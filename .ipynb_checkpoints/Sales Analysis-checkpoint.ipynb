# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
import os

# %% [markdown]
# # Merging Sales Data Together In Single Csv File

# %% [markdown]
# ### Loading Datasets

# %%
df = pd.read_csv('./dataset/Sales_January_2019.csv')

df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# #### Loading all 12 months files

# %%
files = [file for file in os.listdir('./dataset')]

twelve_months_data = pd.DataFrame()

for file in files:
    twelve_months_data = pd.read_csv('./dataset/'+file)
    dataset = pd.concat([dataset, twelve_months_data])
    
    dataset.to_csv('all_twelve_months_data.csv', index = False)

# %% [markdown]
# #### Load The Updated Dataframe

# %%
salesData = pd.read_csv('all_twelve_months_data.csv')

salesData.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %% [markdown]
# # Data Cleaning

# %%
salesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590619 entries, 0 to 590618
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          588885 non-null  object
#  1   Product           588885 non-null  object
#  2   Quantity Ordered  588885 non-null  object
#  3   Price Each        588885 non-null  object
#  4   Order Date        588885 non-null  object
#  5   Purchase Address  588885 non-null  object
# dtypes: object(6)
# memory usage: 27.0+ MB

# %% [markdown]
# ######  Drop NAN Data

# %%
salesData.isnull().sum()
# Out:
# Order ID            1734
# Product             1734
# Quantity Ordered    1734
# Price Each          1734
# Order Date          1734
# Purchase Address    1734
# dtype: int64

# %%
nanData = salesData[salesData.isna().any(axis=1)]
nanData.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 198       NaN     NaN              NaN        NaN        NaN              NaN
# 574       NaN     NaN              NaN        NaN        NaN              NaN
# 776       NaN     NaN              NaN        NaN        NaN              NaN
# 1383      NaN     NaN              NaN        NaN        NaN              NaN
# 1436      NaN     NaN              NaN        NaN        NaN              NaN

# %%
nanData.shape
# Out:
# (1734, 6)

# %%
salesData = salesData.dropna(how = 'all')

# %% [markdown]
# ###### Change DataType

# %%
salesData['Quantity Ordered'] = pd.to_numeric(salesData['Quantity Ordered'])
salesData['Price Each'] = pd.to_numeric(salesData['Price Each'])

salesData.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#        Order Date                       Purchase Address
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001
# 1  09/29/19 10:19           511 8th St, Austin, TX 73301
# 2  09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001
# 3  09/27/19 07:52      355 Hickory St, Seattle, WA 98101
# 4  09/01/19 19:03          125 5th St, Atlanta, GA 30301

# %% [markdown]
# ###### Remove characters from 'Order Date' Column

# %%
findChar= salesData[salesData['Order Date'].str[0:2] == 'Or']
findChar.head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1679  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3732  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3790  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4323  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5579  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 1679  Purchase Address
# 3732  Purchase Address
# 3790  Purchase Address
# 4323  Purchase Address
# 5579  Purchase Address

# %%
salesData= salesData[salesData['Order Date'].str[0:2] != 'Or']

# %% [markdown]
# ### Adding Additional Columns

# %% [markdown]
# ###### Add Month Column

# %%
salesData['Date By Month'] = salesData['Order Date'].str[0:2]
salesData['Date By Month'] = salesData['Date By Month'].astype('int32')
salesData.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#        Order Date                       Purchase Address  Total Sales  \
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001        15.36
# 1  09/29/19 10:19           511 8th St, Austin, TX 73301        23.90
# 2  09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001        11.95
# 3  09/27/19 07:52      355 Hickory St, Seattle, WA 98101       149.99
# 4  09/01/19 19:03          125 5th St, Atlanta, GA 30301        11.95
#
#            City  Date By Month
# 0   Los Angeles              9
# 1        Austin              9
# 2   Los Angeles              9
# 3       Seattle              9
# 4       Atlanta              9

# %% [markdown]
# ###### Add Column Which Calculate Total Sales in a day

# %%
salesData['Total Sales'] = salesData['Quantity Ordered'] * salesData['Price Each']
salesData.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#        Order Date                       Purchase Address  Total Sales
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001        15.36
# 1  09/29/19 10:19           511 8th St, Austin, TX 73301        23.90
# 2  09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001        11.95
# 3  09/27/19 07:52      355 Hickory St, Seattle, WA 98101       149.99
# 4  09/01/19 19:03          125 5th St, Atlanta, GA 30301        11.95

# %% [markdown]
# ###### Split City & State From Adderss In a New Column

# %%
def getCity(address):
    return address.split(",")[1]

def getState(address):
    return address.split(",")[2]

salesData['City'] = salesData['Purchase Address'].apply(lambda x: getCity(x))
salesData['State'] = salesData['Purchase Address'].apply(lambda x: getState(x))

salesData.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#        Order Date                       Purchase Address  Total Sales  \
# 0  09/17/19 14:44    380 North St, Los Angeles, CA 90001        15.36
# 1  09/29/19 10:19           511 8th St, Austin, TX 73301        23.90
# 2  09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001        11.95
# 3  09/27/19 07:52      355 Hickory St, Seattle, WA 98101       149.99
# 4  09/01/19 19:03          125 5th St, Atlanta, GA 30301        11.95
#
#            City  Date By Month      State
# 0   Los Angeles              9   CA 90001
# 1        Austin              9   TX 73301
# 2   Los Angeles              9   CA 90001
# 3       Seattle              9   WA 98101
# 4       Atlanta              9   GA 30301

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### What was the best month for sales? How much was earned that month?

# %%
BestMonthSales = salesData.groupby('Date By Month').sum()
BestMonthSales.head(12)
# Out:
#                Quantity Ordered   Price Each  Total Sales
# Date By Month
# 1                         32709   5435305.14   5466770.19
# 2                         40347   6566654.16   6606067.26
# 3                         51015   8373623.49   8421301.14
# 4                         82213  13465516.65  13557510.54
# 5                         56030   9415930.84   9468379.54
# 6                         45759   7686076.83   7733406.78
# 7                         48216   7897618.68   7943327.28
# 8                         40344   6691036.26   6733403.64
# 9                         52424   8337871.62   8388143.78
# 10                        68131  11150011.82  11213533.95
# 11                        59394   9541802.04   9598809.60
# 12                        84342  13765246.23  13840330.02

# %%
monthsLabel = range(1,13)

plt.bar(monthsLabel, BestMonthSales['Total Sales'])
plt.xticks(monthsLabel)
plt.ticklabel_format(style = 'plain')
plt.title('The Best Month For Sales', color='green')
plt.ylabel('Sales in USD ($)')
plt.xlabel('Months')
plt.figure()

# %% [markdown]
# ### What city has the highest number of sales?

# %%
SalesInCity = salesData.groupby('City').sum()
SalesInCity
# Out:
#                 Quantity Ordered   Price Each  Total Sales  Date By Month
# City
#  Atlanta                   52474   8792528.33   8842229.55         328506
#  Austin                    35317   5707061.29   5738039.43         219376
#  Boston                    71229  11509523.79  11586174.92         442562
#  Dallas                    52763   8672651.52   8720982.52         327678
#  Los Angeles              105391  17164965.26  17263329.89         654042
#  New York City             88248  14648213.20  14740830.84         550787
#  Portland                  44387   7295530.33   7335549.42         274897
#  San Francisco            158790  25906589.54  26068216.15         988933
#  Seattle                   52325   8629630.50   8675631.00         329025

# %%
CityLabel = salesData['City'].unique()

plt.bar(CityLabel, SalesInCity['Total Sales'])
plt.xticks(CityLabel, rotation='vertical', size=8)
plt.title('The Heighst City in Sales', color='Red')
plt.ylabel('Sales in USD ($)')
plt.xlabel('City')
plt.figure()

# %% [markdown]
# ### what time should we display advertisments to maximize likelihood of customer's buying product?

# %%
salesData['Order Date'] = pd.to_datetime(salesData['Order Date'])

salesData.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#            Order Date                       Purchase Address  Total Sales  \
# 0 2019-09-17 14:44:00    380 North St, Los Angeles, CA 90001        15.36
# 1 2019-09-29 10:19:00           511 8th St, Austin, TX 73301        23.90
# 2 2019-09-16 17:48:00  151 Johnson St, Los Angeles, CA 90001        11.95
# 3 2019-09-27 07:52:00      355 Hickory St, Seattle, WA 98101       149.99
# 4 2019-09-01 19:03:00          125 5th St, Atlanta, GA 30301        11.95
#
#            City  Date By Month      State
# 0   Los Angeles              9   CA 90001
# 1        Austin              9   TX 73301
# 2   Los Angeles              9   CA 90001
# 3       Seattle              9   WA 98101
# 4       Atlanta              9   GA 30301

# %%
salesData['Hour'] = salesData['Order Date'].dt.hour
salesData['Minute'] = salesData['Order Date'].dt.minute

salesData.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#            Order Date                       Purchase Address  Total Sales  \
# 0 2019-09-17 14:44:00    380 North St, Los Angeles, CA 90001        15.36
# 1 2019-09-29 10:19:00           511 8th St, Austin, TX 73301        23.90
# 2 2019-09-16 17:48:00  151 Johnson St, Los Angeles, CA 90001        11.95
# 3 2019-09-27 07:52:00      355 Hickory St, Seattle, WA 98101       149.99
# 4 2019-09-01 19:03:00          125 5th St, Atlanta, GA 30301        11.95
#
#            City  Date By Month      State  Hour  Minute
# 0   Los Angeles              9   CA 90001    14      44
# 1        Austin              9   TX 73301    10      19
# 2   Los Angeles              9   CA 90001    17      48
# 3       Seattle              9   WA 98101     7      52
# 4       Atlanta              9   GA 30301    19       3

# %%
hours = [hour for hour, df in salesData.groupby('Hour')]

plt.plot(hours, salesData.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Time in Hours')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

#  12 AM & 7 PM is the best time to display advertisments

# %% [markdown]
# ### What Products sold the most? Why do you think it sold the most?

# %%
productGroup = salesData.groupby('Product')
quantityOrdered = productGroup.sum()['Quantity Ordered']
products = [products for products, df in productGroup]
plt.bar(products, quantityOrdered)
plt.xticks(products, rotation='vertical', size=8)
plt.title('The Heighst City in Sales', color='Red')
plt.ylabel('Quantity Ordered')
plt.xlabel('Product')
plt.figure()

# %%
#why this product sold the most
prices = salesData.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, quantityOrdered,color='g')
ax2.plot(products,prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered',color='g')
ax2.set_ylabel('Price($)',color='b')
ax1.set_xticklabels(products, rotation='vertical', size=8)
plt.show()
